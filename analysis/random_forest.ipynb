# %% [markdown]
# # Random Forest — Tres Modelos por Régimen Educativo
# ## Predicción de Deserción Estudiantil
# **Equipo 7 · Desarrollo de Aplicaciones Avanzadas de Ciencias Computacionales**
#
# ---
# Entrena tres modelos de Random Forest y compara sus métricas (Precision, Recall, F1) y valores SHAP:
#
# | Modelo | Datos de entrenamiento |
# |--------|------------------------|
# | **Todos** | Todos los alumnos (PreTec21 + Tec21) |
# | **PreTec21** | Solo alumnos con `educational.model == 0` |
# | **Tec21** | Solo alumnos con `educational.model == 1` |

# %% [markdown]
# ## Instalación de dependencias

# %%
import importlib, subprocess, sys
if importlib.util.find_spec('shap') is None:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'shap', '-q'])
print('shap disponible:', importlib.util.find_spec('shap') is not None)
# Out:
# shap disponible: True

# %% [markdown]
# ## Importación de librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings, time
from pathlib import Path

import shap

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    classification_report, confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

warnings.filterwarnings('ignore')
print('Librerías cargadas correctamente.')
print(f'  shap     : {shap.__version__}')
print(f'  sklearn  : {__import__("sklearn").__version__}')
print(f'  pandas   : {pd.__version__}')
print(f'  numpy    : {np.__version__}')
# Out:
# Librerías cargadas correctamente.
#   shap     : 0.49.1
#   sklearn  : 1.6.1
#   pandas   : 2.2.3
#   numpy    : 2.0.2

# %% [markdown]
# ## Variables globales

# %%
SEED     = 42
TARGET   = 'retention'
N_SPLITS = 5
DATA_DIR = Path('../data')

np.random.seed(SEED)

# %% [markdown]
# ## Carga de datos
# La primera ejecución lee el `.xlsx` (~30 s) y guarda un CSV caché. Las siguientes leen el CSV (~3 s).

# %%
CACHE_CSV = DATA_DIR / 'dataset_cache.csv'
XLSX_PATH = DATA_DIR / 'dataset.xlsx'

if CACHE_CSV.exists():
    t0 = time.time()
    df_raw = pd.read_csv(CACHE_CSV, low_memory=False)
    print(f'✓ Cache CSV cargado en {time.time()-t0:.1f}s  →  {df_raw.shape}')
else:
    print('Primera carga desde xlsx (puede tardar ~30s)...')
    t0 = time.time()
    df_raw = pd.read_excel(XLSX_PATH, engine='openpyxl')
    df_raw.to_csv(CACHE_CSV, index=False)
    print(f'✓ Xlsx leído y cache guardado en {time.time()-t0:.1f}s  →  {df_raw.shape}')
# Out:
# ✓ Cache CSV cargado en 0.8s  →  (143326, 50)

# %% [markdown]
# ## Preprocesamiento
# Mismo pipeline que `exploration.ipynb` y `logistic_regression.ipynb`: filtrado, exclusión de columnas con fuga, imputación MCAR/MAR/MNAR, ingeniería de variables y encoding.
#
# > **Nota:** Random Forest no requiere escalar las variables, por lo que se omite el `StandardScaler`. La imputación sí se mantiene para manejar valores nulos residuales.

# %%
# ── 1. Filtrar universitarios ────────────────────────────────────────────────
df = df_raw[df_raw['level'] == 'Undergraduate'].copy()
print(f'Universitarios: {len(df):,}  |  PreTec21: {(df["educational.model"]==0).sum():,}  |  Tec21: {(df["educational.model"]==1).sum():,}')
# Out:
# Universitarios: 77,517  |  PreTec21: 53,010  |  Tec21: 24,507

# %%
# ── 2. Eliminar columnas con fuga o irrelevantes ─────────────────────────────
DROP_COLS = [
    'student.id', 'level',
    'average.first.period', 'failed.subject.first.period', 'dropped.subject.first.period',
    'dropout.semester', 'program', 'id.school.origin',
    'scholarship.type', 'school.cost', 'general.math.eval',
    'parents.exatec', 'father.exatec', 'mother.exatec',
    'father.education.complete', 'father.education.summary',
    'mother.education.complete', 'mother.education.summary',
    'scholarship.perc', 'loan.perc',
]
df.drop(columns=[c for c in DROP_COLS if c in df.columns], inplace=True)
print(f'Columnas tras exclusión: {df.shape[1]}')
# Out:
# Columnas tras exclusión: 30

# %%
# ── 3. MCAR: normalizar admission.test ──────────────────────────────────────
def norm_admission_test(val):
    if pd.isna(val): return np.nan
    s = str(val).strip()
    if s.lower().startswith('does not'): return np.nan
    try:
        f = float(s)
        return max(0.0, (f - 400) / 1200.0) if f > 100 else f / 100.0
    except Exception:
        return np.nan

df['admission_test_norm'] = df['admission.test'].apply(norm_admission_test)
df.drop(columns=['admission.test'], inplace=True)

med_at = df['admission_test_norm'].median()
med_ar = df['admission.rubric'].median()
df['admission_test_norm'].fillna(med_at, inplace=True)
df['admission.rubric'].fillna(med_ar, inplace=True)
print(f'admission_test_norm imputado con mediana: {med_at:.3f}')
print(f'admission.rubric    imputado con mediana: {med_ar:.2f}')
# Out:
# admission_test_norm imputado con mediana: 0.808
# admission.rubric    imputado con mediana: 36.00

# %%
# ── 4. MAR: bandera has_extracurriculars ─────────────────────────────────────
ACTIVITY_COLS = [
    'physical.education', 'cultural.diffusion', 'student.society',
    'total.life.activities', 'athletic.sports', 'art.culture',
    'student.society.leadership', 'life.work.mentoring', 'wellness.activities'
]

def parse_activity(val):
    if pd.isna(val): return 0
    s = str(val).strip()
    if s in ('Does not apply', 'No information', '', '0', '0.0'): return 0
    try: return int(float(s) > 0)
    except Exception: return 0

df['has_extracurriculars'] = df['total.life.activities'].apply(parse_activity)
df.drop(columns=[c for c in ACTIVITY_COLS if c in df.columns], inplace=True)
print(f'has_extracurriculars — con actividades: {df["has_extracurriculars"].sum():,} ({df["has_extracurriculars"].mean()*100:.1f}%)')
# Out:
# has_extracurriculars — con actividades: 30,371 (39.2%)

# %%
# ── 5. MNAR: first.generation → 3 categorías ────────────────────────────────
def encode_first_gen(val):
    s = str(val).strip()
    if s == 'Yes': return 1
    if s == 'No':  return 0
    return -1

df['first_gen_enc'] = df['first.generation'].apply(encode_first_gen)
df.drop(columns=['first.generation'], inplace=True)

# %%
# ── 6. Ingeniería y encoding de categóricas ──────────────────────────────────
EDU_ORD = {'No information': 0, 'No degree': 1, 'Undergraduate degree': 2, 'Master degree': 3, 'PhD': 4}
df['educ_padres_max'] = df['max.degree.parents'].map(EDU_ORD).fillna(0).astype(int)
df.drop(columns=['max.degree.parents'], inplace=True)

df.rename(columns={'total.scholarship.loan': 'apoyo_financiero'}, inplace=True)

df['gender_enc']     = df['gender'].map({'Male': 1, 'Female': 0}).fillna(0).astype(int)
df['tec_enc']        = df['tec.no.tec'].map({'TEC': 1, 'NO TEC': 0}).fillna(0).astype(int)
df['foreign_enc']    = df['foreign'].map({'Local': 0, 'Yes: National': 1, 'Yes: Foreigner': 2}).fillna(0).astype(int)
df['zone_enc']       = df['zone.type'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2, 'No information': 1}).fillna(1).astype(int)

sec_map = {'No information': 0, 'Level 1': 1, 'Level 2': 2, 'Level 3': 3,
           'Level 4': 4, 'Level 5': 5, 'Level 6': 6, 'Level 7': 7}
df['socioec_enc']    = df['socioeconomic.level'].map(sec_map).fillna(0).astype(int)

lag_map = {'No information': 0, 'Low': 1, 'Medium': 2, 'High': 3}
df['social_lag_enc'] = df['social.lag'].map(lag_map).fillna(0).astype(int)

le_region = LabelEncoder()
df['region_enc']     = le_region.fit_transform(df['region'].fillna('Unknown'))

le_school = LabelEncoder()
df['school_enc']     = le_school.fit_transform(df['school'].fillna('Unknown'))

df.drop(columns=['gender', 'tec.no.tec', 'foreign', 'zone.type',
                 'socioeconomic.level', 'social.lag', 'region', 'school'], inplace=True)

print('Preprocesamiento completo.')
print(f'Shape final: {df.shape}')
print(f'Columnas: {df.columns.tolist()}')
# Out:
# Preprocesamiento completo.
# Shape final: (77517, 22)
# Columnas: ['generation', 'educational.model', 'age', 'PNA', 'online.test', 'english.evaluation', 'admission.rubric', 'retention', 'FTE', 'apoyo_financiero', 'admission_test_norm', 'has_extracurriculars', 'first_gen_enc', 'educ_padres_max', 'gender_enc', 'tec_enc', 'foreign_enc', 'zone_enc', 'socioec_enc', 'social_lag_enc', 'region_enc', 'school_enc']

# %%
# ── 7. Definir columnas de features ─────────────────────────────────────────
FEATURE_COLS = [
    'PNA', 'admission_test_norm', 'english.evaluation', 'admission.rubric',
    'FTE', 'apoyo_financiero', 'has_extracurriculars',
    'first_gen_enc', 'educ_padres_max',
    'age', 'gender_enc', 'tec_enc', 'foreign_enc',
    'zone_enc', 'socioec_enc', 'social_lag_enc',
    'region_enc', 'school_enc', 'online.test'
]

print(f'Features del modelo: {len(FEATURE_COLS)}')
print(FEATURE_COLS)
# Out:
# Features del modelo: 19
# ['PNA', 'admission_test_norm', 'english.evaluation', 'admission.rubric', 'FTE', 'apoyo_financiero', 'has_extracurriculars', 'first_gen_enc', 'educ_padres_max', 'age', 'gender_enc', 'tec_enc', 'foreign_enc', 'zone_enc', 'socioec_enc', 'social_lag_enc', 'region_enc', 'school_enc', 'online.test']

# %% [markdown]
# ## Definición de los tres subconjuntos de entrenamiento
#
# | Modelo | Filtro | Estrategia de evaluación |
# |--------|--------|---------------------------|
# | **Todos** | PreTec21 + Tec21 | Stratified 5-Fold CV |
# | **PreTec21** | `educational.model == 0` | Stratified 5-Fold CV |
# | **Tec21** | `educational.model == 1` | Stratified 5-Fold CV |

# %%
mask_all    = pd.Series([True] * len(df), index=df.index)
mask_pretec = df['educational.model'] == 0
mask_tec21  = df['educational.model'] == 1

subsets = {
    'Todos'   : mask_all,
    'PreTec21': mask_pretec,
    'Tec21'   : mask_tec21,
}

for name, mask in subsets.items():
    sub = df.loc[mask]
    n_dropout = (sub[TARGET] == 0).sum()
    print(f'{name:10s}: {mask.sum():>6,} alumnos  |  desertores: {n_dropout:,} ({n_dropout/mask.sum()*100:.1f}%)')
# Out:
# Todos     : 77,517 alumnos  |  desertores: 6,813 (8.8%)
# PreTec21  : 53,010 alumnos  |  desertores: 4,685 (8.8%)
# Tec21     : 24,507 alumnos  |  desertores: 2,128 (8.7%)

# %% [markdown]
# ## Función auxiliar — Entrenar y evaluar (Random Forest)

# %%
def train_and_evaluate_rf(X, y, model_name, feature_names, n_splits=5, seed=42):
    """
    Entrena un Random Forest con Stratified K-Fold CV.
    Devuelve el modelo final entrenado en todos los datos y las métricas CV.

    Nota: Random Forest no requiere escalar; se usa solo imputación de seguridad.
    """
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)

    pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('rf', RandomForestClassifier(
            n_estimators=300,
            max_depth=None,
            min_samples_split=5,
            min_samples_leaf=2,
            class_weight='balanced',
            random_state=seed,
            n_jobs=-1
        )),
    ])

    print(f'\n{"="*60}')
    print(f'  Modelo: {model_name}')
    print(f'  N total: {len(y):,}  |  Desertores: {(y==0).sum():,} ({(y==0).mean()*100:.1f}%)')
    print(f'  K-Fold: {n_splits} pliegues estratificados')
    print(f'{"="*60}')

    cv_results = cross_validate(
        pipeline, X, y,
        cv=skf,
        scoring=['precision_weighted', 'recall_weighted', 'f1_weighted'],
        n_jobs=-1
    )

    prec = cv_results['test_precision_weighted']
    rec  = cv_results['test_recall_weighted']
    f1   = cv_results['test_f1_weighted']

    print(f'\n  Métricas CV (media ± std sobre {n_splits} pliegues):')
    print(f'  Precision : {prec.mean():.4f} ± {prec.std():.4f}')
    print(f'  Recall    : {rec.mean():.4f} ± {rec.std():.4f}')
    print(f'  F1-Score  : {f1.mean():.4f} ± {f1.std():.4f}')

    pipeline.fit(X, y)
    print(f'\n  Modelo final entrenado en {len(y):,} muestras.')

    rf_model    = pipeline.named_steps['rf']
    importances = rf_model.feature_importances_
    feat_imp_df = pd.DataFrame({'Feature': feature_names, 'MDI_Importance': importances})
    feat_imp_df = feat_imp_df.sort_values('MDI_Importance', ascending=False).reset_index(drop=True)

    print(f'\n  Top 10 variables por importancia MDI:')
    print(feat_imp_df.head(10).to_string(index=False))

    metrics = {
        'precision_mean': prec.mean(), 'precision_std': prec.std(),
        'recall_mean'   : rec.mean(),  'recall_std'   : rec.std(),
        'f1_mean'       : f1.mean(),   'f1_std'       : f1.std(),
    }
    return pipeline, metrics, feat_imp_df

# %% [markdown]
# ## Función auxiliar — SHAP values
#
# Se usa `shap.Explainer` (API unificada), que internamente aplica `TreeExplainer` para Random Forest
# y devuelve siempre un objeto `Explanation` con `.values` de forma bien definida, evitando las
# incompatibilidades de formato entre versiones antiguas y nuevas de SHAP.

# %%
def extract_shap_values(rf_model, X_sample, n_features):
    """
    Extrae SHAP values para la clase 1 (retención) usando TreeExplainer directamente.
    check_additivity=False evita el error por diferencias de punto flotante en RF.
    Devuelve siempre un array 2D (n_samples, n_features).
    """
    explainer = shap.TreeExplainer(rf_model)
    raw = explainer.shap_values(X_sample, check_additivity=False)

    # IMPORTANTE: checar isinstance ANTES de np.array().
    # Si raw es lista [class0, class1], np.array() la convierte en (2, n, feat)
    # y sv[:, :, 1] tomaría la feature 1, no la clase 1.
    if isinstance(raw, list):
        # Formato antiguo: [array(n,f), array(n,f)] — tomar clase 1
        sv = np.array(raw[-1], dtype=float)
    else:
        sv = np.array(raw, dtype=float)
        if sv.ndim == 3:
            # Formato nuevo: (n_samples, n_features, n_classes)
            sv = sv[:, :, -1]

    # Garantía final
    if sv.ndim != 2:
        sv = sv.reshape(len(X_sample), n_features)
    return sv


def plot_shap_rf(pipeline, X_raw, feature_names, model_name, max_display=15):
    """
    Calcula y grafica los SHAP values para un pipeline RF entrenado.
    """
    imputer  = pipeline.named_steps['imputer']
    rf_model = pipeline.named_steps['rf']
    n_feat   = len(feature_names)

    X_imputed = imputer.transform(X_raw)

    # Submuestra de hasta 800 filas
    rng      = np.random.default_rng(42)
    n_sample = min(800, X_imputed.shape[0])
    idx      = rng.choice(X_imputed.shape[0], size=n_sample, replace=False)
    X_sample = X_imputed[idx]

    print(f'\n  Calculando SHAP values — {model_name} (muestra: {n_sample:,} alumnos)...')
    sv = extract_shap_values(rf_model, X_sample, n_feat)
    print(f'  Shape final de shap_values: {sv.shape}  ✓')

    # ── Beeswarm plot ────────────────────────────────────────────────────────
    plt.figure(figsize=(10, 6))
    shap.summary_plot(
        sv, X_sample,
        feature_names=list(feature_names),
        max_display=max_display,
        show=False
    )
    plt.title(f'SHAP Values (Beeswarm) — {model_name}', fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()

    # ── Bar plot ─────────────────────────────────────────────────────────────
    plt.figure(figsize=(9, 5))
    shap.summary_plot(
        sv, X_sample,
        feature_names=list(feature_names),
        plot_type='bar',
        max_display=max_display,
        show=False
    )
    plt.title(f'SHAP — Importancia media |SHAP| — {model_name}', fontsize=12, fontweight='bold')
    plt.tight_layout()
    plt.show()

    # ── Tabla resumen ─────────────────────────────────────────────────────────
    mean_abs = np.abs(sv).mean(axis=0)           # shape: (n_features,)
    shap_df  = pd.DataFrame({
        'Feature'     : list(feature_names),
        'mean_|SHAP|' : mean_abs.tolist(),        # .tolist() garantiza lista 1D plana
    })
    shap_df = shap_df.sort_values('mean_|SHAP|', ascending=False).reset_index(drop=True)
    print(f'\n  Top {max_display} variables por |SHAP| medio — {model_name}:')
    print(shap_df.head(max_display).to_string(index=False))

    return shap_df

# %% [markdown]
# ---
# ## Modelo 1 — Todos los alumnos (PreTec21 + Tec21)

# %%
mask = mask_all
X_all = df.loc[mask, FEATURE_COLS].values
y_all = df.loc[mask, TARGET].values

pipeline_all, metrics_all, feat_imp_all = train_and_evaluate_rf(
    X_all, y_all,
    model_name='Todos los alumnos',
    feature_names=FEATURE_COLS
)
# Out:
# ============================================================
#   Modelo: Todos los alumnos
#   N total: 77,517  |  Desertores: 6,813 (8.8%)
#   K-Fold: 5 pliegues estratificados
# ============================================================
#
#   Métricas CV (media ± std sobre 5 pliegues):
#   Precision : 0.8598 ± 0.0031
#   Recall    : 0.9073 ± 0.0009
#   F1-Score  : 0.8735 ± 0.0009
#
#   Modelo final entrenado en 77,517 muestras.
#
#   Top 10 variables por importancia MDI:
#             Feature  MDI_Importance
#                 PNA        0.206555
# admission_test_norm        0.133467
#    apoyo_financiero        0.095429
#    admission.rubric        0.080964
#                 FTE        0.067958
#          region_enc        0.059465
#  english.evaluation        0.059455
#          school_enc        0.058167
#                 age        0.056013
#     educ_padres_max        0.036257

# %%
shap_df_all = plot_shap_rf(
    pipeline_all, X_all, FEATURE_COLS,
    model_name='Todos los alumnos'
)
# Out:
#   Calculando SHAP values — Todos los alumnos (muestra: 800 alumnos)...
#   Shape final de shap_values: (800, 19)  ✓
#   Top 15 variables por |SHAP| medio — Todos los alumnos:
#              Feature  mean_|SHAP|
#                  PNA     0.068854
#     apoyo_financiero     0.050907
#  admission_test_norm     0.043866
#                  FTE     0.031845
#   english.evaluation     0.031006
#     admission.rubric     0.027742
#           region_enc     0.026901
#                  age     0.026274
#           school_enc     0.020213
# has_extracurriculars     0.020154
#      educ_padres_max     0.013900
#           gender_enc     0.011676
#          foreign_enc     0.010856
#              tec_enc     0.009014
#        first_gen_enc     0.007882

# %% [markdown]
# ---
# ## Modelo 2 — PreTec21 (`educational.model == 0`)

# %%
mask = mask_pretec
X_pretec = df.loc[mask, FEATURE_COLS].values
y_pretec = df.loc[mask, TARGET].values

pipeline_pretec, metrics_pretec, feat_imp_pretec = train_and_evaluate_rf(
    X_pretec, y_pretec,
    model_name='PreTec21 (educational.model == 0)',
    feature_names=FEATURE_COLS
)
# Out:
# ============================================================
#   Modelo: PreTec21 (educational.model == 0)
#   N total: 53,010  |  Desertores: 4,685 (8.8%)
#   K-Fold: 5 pliegues estratificados
# ============================================================
#
#   Métricas CV (media ± std sobre 5 pliegues):
#   Precision : 0.8586 ± 0.0023
#   Recall    : 0.9055 ± 0.0008
#   F1-Score  : 0.8731 ± 0.0008
#
#   Modelo final entrenado en 53,010 muestras.
#
#   Top 10 variables por importancia MDI:
#             Feature  MDI_Importance
#                 PNA        0.223018
# admission_test_norm        0.140624
#    apoyo_financiero        0.105370
#    admission.rubric        0.085064
#  english.evaluation        0.067478
#          region_enc        0.063991
#                 FTE        0.061415
#                 age        0.061306
#          school_enc        0.057855
#     educ_padres_max        0.032350

# %%
shap_df_pretec = plot_shap_rf(
    pipeline_pretec, X_pretec, FEATURE_COLS,
    model_name='PreTec21'
)
# Out:
#   Calculando SHAP values — PreTec21 (muestra: 800 alumnos)...
#   Shape final de shap_values: (800, 19)  ✓
#   Top 15 variables por |SHAP| medio — PreTec21:
#              Feature  mean_|SHAP|
#                  PNA     0.071889
#     apoyo_financiero     0.047347
#  admission_test_norm     0.047073
#   english.evaluation     0.035803
#                  FTE     0.035469
#           region_enc     0.032210
#     admission.rubric     0.029533
#                  age     0.027284
#           school_enc     0.020317
#          foreign_enc     0.012202
#           gender_enc     0.012178
#      educ_padres_max     0.012040
#              tec_enc     0.010520
# has_extracurriculars     0.010229
#        first_gen_enc     0.007329

# %% [markdown]
# ---
# ## Modelo 3 — Tec21 (`educational.model == 1`)

# %%
mask = mask_tec21
X_tec21 = df.loc[mask, FEATURE_COLS].values
y_tec21 = df.loc[mask, TARGET].values

pipeline_tec21, metrics_tec21, feat_imp_tec21 = train_and_evaluate_rf(
    X_tec21, y_tec21,
    model_name='Tec21 (educational.model == 1)',
    feature_names=FEATURE_COLS
)
# Out:
# ============================================================
#   Modelo: Tec21 (educational.model == 1)
#   N total: 24,507  |  Desertores: 2,128 (8.7%)
#   K-Fold: 5 pliegues estratificados
# ============================================================
#
#   Métricas CV (media ± std sobre 5 pliegues):
#   Precision : 0.8602 ± 0.0054
#   Recall    : 0.9107 ± 0.0009
#   F1-Score  : 0.8735 ± 0.0008
#
#   Modelo final entrenado en 24,507 muestras.
#
#   Top 10 variables por importancia MDI:
#             Feature  MDI_Importance
#                 PNA        0.180761
# admission_test_norm        0.126441
#    admission.rubric        0.080649
#    apoyo_financiero        0.073822
#          region_enc        0.064728
#          school_enc        0.064242
#                 FTE        0.057006
#  english.evaluation        0.055464
#                 age        0.050521
#         socioec_enc        0.043623

# %%
shap_df_tec21 = plot_shap_rf(
    pipeline_tec21, X_tec21, FEATURE_COLS,
    model_name='Tec21'
)
# Out:
#   Calculando SHAP values — Tec21 (muestra: 800 alumnos)...
#   Shape final de shap_values: (800, 19)  ✓
#   Top 15 variables por |SHAP| medio — Tec21:
#              Feature  mean_|SHAP|
#                  PNA     0.064422
#     apoyo_financiero     0.052425
#  admission_test_norm     0.043419
# has_extracurriculars     0.031994
#     admission.rubric     0.029121
#           region_enc     0.027860
#                  FTE     0.025584
#   english.evaluation     0.023412
#           school_enc     0.023304
#                  age     0.023245
#      educ_padres_max     0.020043
#          socioec_enc     0.016126
#           gender_enc     0.013114
#       social_lag_enc     0.010346
#        first_gen_enc     0.010179

# %% [markdown]
# ---
# ## Comparación de los tres modelos

# %%
comparison = pd.DataFrame({
    'Modelo'    : ['Todos', 'PreTec21', 'Tec21'],
    'N'         : [len(y_all), len(y_pretec), len(y_tec21)],
    'Precision' : [f"{metrics_all['precision_mean']:.4f} ± {metrics_all['precision_std']:.4f}",
                   f"{metrics_pretec['precision_mean']:.4f} ± {metrics_pretec['precision_std']:.4f}",
                   f"{metrics_tec21['precision_mean']:.4f} ± {metrics_tec21['precision_std']:.4f}"],
    'Recall'    : [f"{metrics_all['recall_mean']:.4f} ± {metrics_all['recall_std']:.4f}",
                   f"{metrics_pretec['recall_mean']:.4f} ± {metrics_pretec['recall_std']:.4f}",
                   f"{metrics_tec21['recall_mean']:.4f} ± {metrics_tec21['recall_std']:.4f}"],
    'F1-Score'  : [f"{metrics_all['f1_mean']:.4f} ± {metrics_all['f1_std']:.4f}",
                   f"{metrics_pretec['f1_mean']:.4f} ± {metrics_pretec['f1_std']:.4f}",
                   f"{metrics_tec21['f1_mean']:.4f} ± {metrics_tec21['f1_std']:.4f}"],
})

print('\n' + '='*70)
print('  RESUMEN COMPARATIVO — Random Forest')
print('  (Stratified 5-Fold CV · weighted avg · class_weight=balanced)')
print('='*70)
print(comparison.to_string(index=False))
# Out:
# ======================================================================
#   RESUMEN COMPARATIVO — Random Forest
#   (Stratified 5-Fold CV · weighted avg · class_weight=balanced)
# ======================================================================
#   Modelo     N       Precision          Recall        F1-Score
#    Todos 77517 0.8598 ± 0.0031 0.9073 ± 0.0009 0.8735 ± 0.0009
# PreTec21 53010 0.8586 ± 0.0023 0.9055 ± 0.0008 0.8731 ± 0.0008
#    Tec21 24507 0.8602 ± 0.0054 0.9107 ± 0.0009 0.8735 ± 0.0008

# %%
# ── Gráfica comparativa de F1, Precision y Recall ───────────────────────────
modelos  = ['Todos', 'PreTec21', 'Tec21']
all_m    = [metrics_all, metrics_pretec, metrics_tec21]

fig, axes = plt.subplots(1, 3, figsize=(14, 5), sharey=True)
metric_pairs = [
    ('precision_mean', 'precision_std', 'Precision', '#2563eb'),
    ('recall_mean',    'recall_std',    'Recall',    '#059669'),
    ('f1_mean',        'f1_std',        'F1-Score',  '#d97706'),
]

for ax, (mean_key, std_key, label, color) in zip(axes, metric_pairs):
    means = [m[mean_key] for m in all_m]
    stds  = [m[std_key]  for m in all_m]
    bars  = ax.bar(modelos, means, yerr=stds, color=color, alpha=0.85,
                   capsize=6, edgecolor='white')
    ax.set_title(label, fontsize=13, fontweight='bold')
    ax.set_ylim(0, 1.05)
    ax.set_ylabel('Score')
    ax.grid(axis='y', alpha=0.3)
    for bar, mean in zip(bars, means):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
                f'{mean:.3f}', ha='center', va='bottom', fontsize=10)

plt.suptitle('Comparación de métricas por modelo — Random Forest\n(CV 5-Fold, weighted, class_weight=balanced)',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# ── Top 10 variables por importancia MDI ─────────────────────────────────────
print('\nTop 10 variables por importancia MDI (Mean Decrease in Impurity):')
print('\n  Todos:')
print(feat_imp_all.head(10)[['Feature', 'MDI_Importance']].to_string(index=False))
print('\n  PreTec21:')
print(feat_imp_pretec.head(10)[['Feature', 'MDI_Importance']].to_string(index=False))
print('\n  Tec21:')
print(feat_imp_tec21.head(10)[['Feature', 'MDI_Importance']].to_string(index=False))
# Out:
# Top 10 variables por importancia MDI (Mean Decrease in Impurity):
#
#   Todos:
#             Feature  MDI_Importance
#                 PNA        0.206555
# admission_test_norm        0.133467
#    apoyo_financiero        0.095429
#    admission.rubric        0.080964
#                 FTE        0.067958
#          region_enc        0.059465
#  english.evaluation        0.059455
#          school_enc        0.058167
#                 age        0.056013
#     educ_padres_max        0.036257
#
#   PreTec21:
#             Feature  MDI_Importance
#                 PNA        0.223018
# admission_test_norm        0.140624
#    apoyo_financiero        0.105370
#    admission.rubric        0.085064
#  english.evaluation        0.067478
#          region_enc        0.063991
#                 FTE        0.061415
#                 age        0.061306
#          school_enc        0.057855
#     educ_padres_max        0.032350
#
#   Tec21:
#             Feature  MDI_Importance
#                 PNA        0.180761
# admission_test_norm        0.126441
#    admission.rubric        0.080649
#    apoyo_financiero        0.073822
#          region_enc        0.064728
#          school_enc        0.064242
#                 FTE        0.057006
#  english.evaluation        0.055464
#                 age        0.050521
#         socioec_enc        0.043623

# %%
# ── Top 10 variables SHAP más importantes por modelo ────────────────────────
print('\nTop 10 variables por |SHAP| medio — comparación entre modelos:')
print('\n  Todos:')
print(shap_df_all.head(10)[['Feature', 'mean_|SHAP|']].to_string(index=False))
print('\n  PreTec21:')
print(shap_df_pretec.head(10)[['Feature', 'mean_|SHAP|']].to_string(index=False))
print('\n  Tec21:')
print(shap_df_tec21.head(10)[['Feature', 'mean_|SHAP|']].to_string(index=False))
# Out:
# Top 10 variables por |SHAP| medio — comparación entre modelos:
#
#   Todos:
#              Feature  mean_|SHAP|
#                  PNA     0.068854
#     apoyo_financiero     0.050907
#  admission_test_norm     0.043866
#                  FTE     0.031845
#   english.evaluation     0.031006
#     admission.rubric     0.027742
#           region_enc     0.026901
#                  age     0.026274
#           school_enc     0.020213
# has_extracurriculars     0.020154
#
#   PreTec21:
#             Feature  mean_|SHAP|
#                 PNA     0.071889
#    apoyo_financiero     0.047347
# admission_test_norm     0.047073
#  english.evaluation     0.035803
#                 FTE     0.035469
#          region_enc     0.032210
#    admission.rubric     0.029533
#                 age     0.027284
#          school_enc     0.020317
#         foreign_enc     0.012202
#
#   Tec21:
#              Feature  mean_|SHAP|
#                  PNA     0.064422
#     apoyo_financiero     0.052425
#  admission_test_norm     0.043419
# has_extracurriculars     0.031994
#     admission.rubric     0.029121
#           region_enc     0.027860
#                  FTE     0.025584
#   english.evaluation     0.023412
#           school_enc     0.023304
#                  age     0.023245
